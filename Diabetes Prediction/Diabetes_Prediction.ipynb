# %% [markdown]
# Import the essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Import / Collect the Data**

# %%
# load the diabetes dataset into the pandas dataframe
diabetes_data = pd.read_csv(f"/content/diabetes.csv")

#let us see first 5 rows of dataset
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Insights from the data:
# All the columns have numerical values, so we do not have to do text-preprocessing.

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# let us see the number of rows and columns in this data set
diabetes_data.shape
# Out:
# (768, 9)

# %%
# Now let us see the information about the dataset
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# From the above output, we can see that we do not have any NaN values, so we do not have to delete any rows or do any imputation.
# Also, all the values of numerical types

# %%
# Let us see the statistical measure of the data
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Now, let us see whether the dataset is biased or not.
diabetes_data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# We see 500 are non-diabetic and 268 are diabetic.

# %%
# Now let us see and group the data-set
diabetes_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Check for missing values

# %%
# to check if we have any missing values
diabetes_data.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
# to check for columns which has any missing values
diabetes_data.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
# to check for rows which has any missing values
diabetes_data.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
corr = diabetes_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d1954_row0_col0, #T_d1954_row1_col1, #T_d1954_row2_col2, #T_d1954_row3_col3, #T_d1954_row4_col4, #T_d1954_row5_col5, #T_d1954_row6_col6, #T_d1954_row7_col7, #T_d1954_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d1954_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d1954_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d1954_row0_col3, #T_d1954_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d1954_row0_col4, #T_d1954_row0_col5, #T_d1954_row0_col6, #T_d1954_row2_col8, #T_d1954_row3_col0, #T_d1954_row3_col1, #T_d1954_row3_col7, #T_d1954_row6_col2, #T_d1954_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d1954_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_d1954_row0_col8, #T_d1954_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d1954_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_d1954_row1_col2, #T_d1954_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d1954_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_d1954_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d1954_row1_col5, #T_d1954_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_d1954_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d1954_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_d1954_row2_col0, #T_d1954_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_d1954_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d1954_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d1954_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d1954_row2_col5, #T_d1954_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d1954_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d1954_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d1954_row3_col2, #T_d1954_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d1954_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d1954_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d1954_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d1954_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d1954_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col7, #T_d1954_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d1954_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d1954_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d1954_row5_col2, #T_d1954_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_d1954_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d1954_row5_col6, #T_d1954_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d1954_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d1954_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d1954_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d1954_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d1954_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_d1954_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d1954_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d1954_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_d1954_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d1954_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d1954_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_d1954_row8_col0, #T_d1954_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d1954_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_d1954_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d1954_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_d1954_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d1954_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_d1954" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1954_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_d1954_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_d1954_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_d1954_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_d1954_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_d1954_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_d1954_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_d1954_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_d1954_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1954_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_d1954_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d1954_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_d1954_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_d1954_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_d1954_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_d1954_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_d1954_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_d1954_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_d1954_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_d1954_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_d1954_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_d1954_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d1954_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_d1954_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_d1954_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_d1954_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_d1954_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_d1954_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_d1954_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_d1954_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_d1954_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_d1954_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_d1954_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d1954_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_d1954_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_d1954_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_d1954_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_d1954_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_d1954_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_d1954_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_d1954_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_d1954_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_d1954_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_d1954_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d1954_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_d1954_row3_col5" class="data row3 col5" >0.392573</td>
#       <

# %% [markdown]
# From the above plot, the main features affecting the diabetes are:
# 1) Glucose
# 2) Insulin
# 3) BMI
# 4) Age
# 5) Pregnancies

# %%
new_data = diabetes_data[['Glucose','Insulin','BMI','Age','Pregnancies','Outcome']]
new_data.head()
# Out:
#    Glucose  Insulin   BMI  Age  Pregnancies  Outcome
# 0      148        0  33.6   50            6        1
# 1       85        0  26.6   31            1        0
# 2      183        0  23.3   32            8        1
# 3       89       94  28.1   21            1        0
# 4      137      168  43.1   33            0        1

# %% [markdown]
# Split the data set

# %%
#Now, we will train out model on  diabetes_data because we have small number of data
X = diabetes_data.drop(columns = ['Outcome'])
X_label = X
y = diabetes_data['Outcome']
#Let us check the shapes of each set
print("Shape of X is ", X.shape)
print("Shape of y is ", y.shape)
# Out:
# Shape of X is  (768, 8)
# Shape of y is  (768,)

# %% [markdown]
# Let us Standardize the Data-set

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
stand_data = scaler.transform(X)
print(stand_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = stand_data

# %% [markdown]
# train and split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size = 0.8, random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %% [markdown]
# Model Evaluation for train data

# %%
y_train_pred = clf.predict(X_train)
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.7719869706840391

# %% [markdown]
# Model Evaluation for test Data

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7792207792207793

# %% [markdown]
# **Let Us make a predictive System**

# %%
input_data = (0,137,40,35,168,43.1,2.288,33)

#changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array to one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# Now, we need to standardize the data
std_data = scaler.transform(input_data_reshaped)

#do prediction
prediction = clf.predict(std_data)

if(prediction[0] == 0):
  print("The person does not have diabetes")
else:
  print("The person has diabetes")
# Out:
# The person has diabetes
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
